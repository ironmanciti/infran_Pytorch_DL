# %% [markdown]
# # 270. 컴퓨터 비전(Vision)을 위한 전이학습(Transfer Learning)
# =======================================================
#
# - 실제로 충분한 크기의 데이터셋을 갖추기는 상대적으로 드물기 때문에, (무작위 초기화를 통해) 처음부터 합성곱 신경망(Convolutional Network) 전체를 작성하는 경우는 매우 적다.
#
#
# - 대신, 매우 큰 데이터셋(예. 100가지 분류에 대해 120만개의 이미지가 포함된 ImageNet)에서 합성곱 신경망(ConvNet)을 미리 학습한 후, 이 합성곱 신경망을 관심있는 작업을 위한 초기 설정 또는 고정된 특징 추출기(fixed feature extractor)로 사용
#
# ### 전이학습의 2 가지 시나리오:
#
# -  **합성곱 신경망의 미세조정(finetuning)**: 신경망을 ImageNet 등으로 미리 학습한 신경망으로 초기화하고 parameter 미세 조정
#
#
# -  **고정된 특징 추출기로써의 합성곱 신경망**: 마지막 완전 연결층을 제외한 모든 신경망의 가중치를 고정. 마지막의 완전 연결층은 새로운 무작위의 가중치를 갖는 계층으로 대체되어 이 계층만 학습.
#
#
# ### torch 제공 pre-trained models
# ```
#     import torchvision.models as models
#
#     resnet18 = models.resnet18()
#     alexnet = models.alexnet()
#     vgg16 = models.vgg16()
#     squeezenet = models.squeezenet1_0()
#     densenet = models.densenet161()
#     inception = models.inception_v3()
#     googlenet = models.googlenet()
#     shufflenet = models.shufflenet_v2_x1_0()
#     mobilenet = models.mobilenet_v2()
#     resnext50_32x4d = models.resnext50_32x4d()
#     wide_resnet50_2 = models.wide_resnet50_2()
#     mnasnet = models.mnasnet1_0()
# ```

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# 데이터 불러오기
# ---------------
#
# - **개미** 와 **벌** 을 분류하는 모델을 학습
#     - 대략 120장 정도의 훈련 이미지와, 75장의 검증용 이미지를 이용
#     - 전이학습을 통해 소량의 데이터로도 일반화 가능
#     - ImageNet의 일부 data 이용
#
# .. Note ::
#    데이터를 `여기` <https://download.pytorch.org/tutorial/hymenoptera_data.zip>
#    에서 다운로드 받아 현재 디렉토리에 압축을 푼다

# %%
# 데이터 증가(augmentation) 및 ResNet 에 적합한 normalization 적용
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),  # ResNet
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # ResNet
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# %% [markdown]
# # ImageFolder 라이브러리
#
# - 계층적인 폴더 구조를 가지고 있는 데이터셋을 불러올 때 사용할 수 있다. 각 이미지들이 자신의 레이블(Label) 이름으로 된 폴더 안에 들어가 있는 구조라면, ImageFolder 라이브러리를 이용하여 이를 바로 불러와 객체로 만들면 된다.

# %%
data_dir = 'hymenoptera_data'
train_dir = os.path.join(data_dir, 'train')
val_dir  = os.path.join(data_dir, 'val')

print(os.listdir(data_dir))
print(os.listdir(train_dir))
print(os.listdir(val_dir))
# Out:
# ['train', 'val']
# ['ants', 'bees']
# ['ants', 'bees']

# %% [markdown]
# ### datasets.ImageFolder(folder, transform) data loader 생성

# %%
train_data = datasets.ImageFolder(os.path.join(data_dir, 'train'),  data_transforms['train']) 
val_data = datasets.ImageFolder(os.path.join(data_dir, 'val'), data_transforms['val'])

train_loader = torch.utils.data.DataLoader(train_data, batch_size=4, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_data, batch_size=4, shuffle=True)

# %%
class_names = train_data.classes
class_names
# Out:
# ['ants', 'bees']

# %%
print(len(train_data), len(val_data))
print(class_names)
# Out:
# 244 153
# ['ants', 'bees']

# %% [markdown]
# ### 일부 이미지 시각화하기
#
# - torchvision.utils.make_grid(tensor)
#     - tensor (Tensor or list) – (B x C x H x W)의 4D 미니 배치 텐서 또는 모두 같은 크기의 이미지 list 입니다.
#     - nrow (int, optional) – 그리드의 각 행에 표시되는 이미지 수입니다. 최종 그리드 크기는 (B / nrow, nrow)입니다. 기본값은 8.

# %%
def imshow(inp, title=None):
    inp = inp.numpy().transpose(1, 2, 0)
    mean = np.array([0.485, 0.456, 0.406])
    std  = np.array([0.229, 0.224, 0.225])
    inp  = inp * std + mean
    inp  = np.clip(inp, 0, 1)
    plt.title(title)
    plt.imshow(inp)

# %%
inputs, classes = next(iter(train_loader))
out = torchvision.utils.make_grid(inputs, nrow=2)
imshow(out, [class_names[x] for x in classes])

# %% [markdown]
# Model Train
# --------------
#
# -  학습율(learning rate) 관리(scheduling)
# -  최적의 모델 구하기
#
# - 아래에서 ``scheduler`` 매개변수는 ``torch.optim.lr_scheduler`` 의 LR 스케쥴러 객체(Object)

# %% [markdown]
# ## 방법 1. pre-trained 합성곱 신경망 미세조정(finetuning)
#
# - 미리 학습된 모델을 불러온 후 마지막의 완전 연결층 만을 새로 작성하고 전체 parameter 를 fine tuning

# %%
model_ft = torchvision.models.resnet18(pretrained=True)

num_features = model_ft.fc.in_features
num_features
# Out:
# 512

# %%
# fc layer 출력의 크기를 1000 에서 2로 변경
model_ft.fc = nn.Linear(num_features, 2)
model_ft.fc
# Out:
# Linear(in_features=512, out_features=2, bias=True)

# %%
model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# 7 에폭마다 0.1 비율로 learning rate decay
scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    st = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs-1))
        print('-' * 10)

        model.train()  
        cost = 0
        corrects = 0

        for x, y in train_loader:
            x, y = x.to(device), y.to(device)

            optimizer.zero_grad()

            z = model(x)
            _, preds = torch.max(z, 1)
        
            loss = criterion(z, y)
            loss.backward()
            optimizer.step()

            cost += loss.item() * x.size(0)
            corrects += torch.sum(preds == y.data)

        train_acc = corrects / len(train_data)  
        train_loss = cost / len(train_data)
        
        scheduler.step()

        model.eval()  
        cost = 0
        corrects = 0
        
        with torch.no_grad():
            for x, y in val_loader:
                x, y = x.to(device), y.to(device)

                z = model(x)
                _, preds = torch.max(z, 1)

                loss = criterion(z, y)

                cost += loss.item() * x.size(0)
                corrects += torch.sum(preds == y.data)

        val_acc  = corrects / len(val_data)    
        val_loss = cost / len(val_data)

        print(f'eEpoch {epoch+1}/{num_epochs}==> train loss: {train_loss:.4f} ' + 
              f'val loss: {val_loss:.4f} ' + f'train acc: {train_acc:.2f} ' + 
              f'val acc: {val_acc:.2f}')

        # 모델을 깊은 복사(deep copy)함
        if val_acc > best_acc:
            best_acc = val_acc
            best_model_wts = copy.deepcopy(model.state_dict())

    time_elapsed = time.time() - st
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Acc: {best_acc:4f}')

    # 가장 나은 모델 가중치를 불러옴
    model.load_state_dict(best_model_wts)
    return model

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, scheduler, num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# eEpoch 1/25==> train loss: 0.6142 val loss: 0.2462 train acc: 0.72 val acc: 0.89
# Epoch 1/24
# ----------
# eEpoch 2/25==> train loss: 0.5848 val loss: 0.6106 train acc: 0.72 val acc: 0.69
# Epoch 2/24
# ----------
# eEpoch 3/25==> train loss: 0.5934 val loss: 0.3227 train acc: 0.74 val acc: 0.88
# Epoch 3/24
# ----------
# eEpoch 4/25==> train loss: 0.4294 val loss: 0.4345 train acc: 0.83 val acc: 0.88
# Epoch 4/24
# ----------
# eEpoch 5/25==> train loss: 0.3936 val loss: 0.2950 train acc: 0.85 val acc: 0.89
# Epoch 5/24
# ----------
# eEpoch 6/25==> train loss: 0.4440 val loss: 0.3223 train acc: 0.82 val acc: 0.88
# Epoch 6/24
# ----------
# eEpoch 7/25==> train loss: 0.3506 val loss: 0.2579 train acc: 0.85 val acc: 0.92
# Epoch 7/24
# ----------
# eEpoch 8/25==> train loss: 0.4142 val loss: 0.2267 train acc: 0.85 val acc: 0.92
# Epoch 8/24
# ----------
# eEpoch 9/25==> train loss: 0.2700 val loss: 0.2135 train acc: 0.89 val acc: 0.93
# Epoch 9/24
# ----------
# eEpoch 10/25==> train loss: 0.3038 val loss: 0.2117 train acc: 0.89 val acc: 0.92
# Epoch 10/24
# ----------
# eEpoch 11/25==> train loss: 0.3132 val loss: 0.2304 train acc: 0.84 val acc: 0.92
# Epoch 11/24
# ----------
# eEpoch 12/25==> train loss: 0.2698 val loss: 0.2386 train acc: 0.89 val acc: 0.92
# Epoch 12/24
# ----------
# eEpoch 13/25==> train loss: 0.2593 val loss: 0.2117 train acc: 0.90 val acc: 0.93
# Epoch 13/24
# ----------
# eEpoch 14/25==> train loss: 0.3147 val loss: 0.2057 train acc: 0.84 val acc: 0.92
# Epoch 14/24
# ----------
# eEpoch 15/25==> train loss: 0.3997 val loss: 0.2171 train acc: 0.82 val acc: 0.93
# Epoch 15/24
# ----------
# eEpoch 16/25==> train loss: 0.2562 val loss: 0.2254 train acc: 0.90 val acc: 0.93
# Epoch 16/24
# ----------
# eEpoch 17/25==> train loss: 0.3256 val loss: 0.1988 train acc: 0.86 val acc: 0.92
# Epoch 17/24
# ----------
# eEpoch 18/25==> train loss: 0.2953 val loss: 0.2101 train acc: 0.86 val acc: 0.93
# Epoch 18/24
# ----------
# eEpoch 19/25==> train loss: 0.2999 val loss: 0.1945 train acc: 0.88 val acc: 0.93
# Epoch 19/24
# ----------
# eEpoch 20/25==> train loss: 0.2182 val loss: 0.1899 train acc: 0.91 val acc: 0.94
# Epoch 20/24
# ----------
# eEpoch 21/25==> train loss: 0.2804 val loss: 0.2105 train acc: 0.89 val acc: 0.93
# Epoch 21/24
# ----------
# eEpoch 22/25==> train loss: 0.2145 val loss: 0.2116 train acc: 0.90 val acc: 0.94
# Epoch 22/24
# ----------
# eEpoch 23/25==> train loss: 0.3183 val loss: 0.2075 train acc: 0.88 val acc: 0.93
# Epoch 23/24
# ----------
# eEpoch 24/25==> train loss: 0.2472 val loss: 0.1902 train acc: 0.90 val acc: 0.94
# Epoch 24/24
# ----------
# eEpoch 25/25==> train loss: 0.2157 val loss: 0.1978 train acc: 0.89 val acc: 0.93
# Training complete in 4m 2s
# Best val Acc: 0.941176

# %%
predictions = []
labels = []

with torch.no_grad():
    for x, y in val_loader:
        x, y = x.to(device), y.to(device)

        z = model_ft(x)
        _, preds = torch.max(z, 1)
        
        predictions.extend(preds.cpu().numpy())
        labels.extend(y.cpu().numpy())
        
    correct_indices = np.nonzero(np.array(predictions) == np.array(labels))[0]
    incorrect_indices = np.nonzero(np.array(predictions) != np.array(labels))[0]

print(f"accuracy = {len(correct_indices) / len(predictions) * 100:.2f} %")
# Out:
# accuracy = 94.12 %

# %%
inputs = []
for i, idx in enumerate(correct_indices[:9]):
    inputs.append(val_data[idx][0])
out = torchvision.utils.make_grid(inputs, nrow=9)
plt.figure(figsize=(12, 4))
imshow(out, 'correct')

inputs = []
for i, idx in enumerate(incorrect_indices[:9]):
    inputs.append(val_data[idx][0])
out = torchvision.utils.make_grid(inputs, nrow=9)
plt.figure(figsize=(12, 4))
imshow(out, 'incorrect')

# %% [markdown]
# 방법2 : 고정된 특징 추출기로써의 합성곱 신경망
# ---------------------------------------
#
# - 마지막 계층을 제외한 신경망의 모든 부분을 고정 (``requires_grad == False`` 로 설정)하여 ``backward()`` 중에 gradient가 계산되지 않도록 함

# %%
model_conv = torchvision.models.resnet18(pretrained=True)

for param in model_conv.parameters():
    param.requires_grad = False

# %%
# 새로 생성된 모듈의 매개변수는 기본값이 requires_grad=True 임
num_features = model_conv.fc.in_features
model_conv.fc = nn.Linear(num_features, 2)

model_conv = model_conv.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_conv = optim.SGD(model_conv.fc.parameters(), lr=0.001, momentum=0.9)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)

# %% [markdown]
# ## Train & Evaluation

# %%
model_conv = train_model(model_conv, criterion, optimizer_conv,
                         exp_lr_scheduler, num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# eEpoch 1/25==> train loss: 0.6241 val loss: 0.2262 train acc: 0.67 val acc: 0.93
# Epoch 1/24
# ----------
# eEpoch 2/25==> train loss: 0.5854 val loss: 0.2075 train acc: 0.71 val acc: 0.93
# Epoch 2/24
# ----------
# eEpoch 3/25==> train loss: 0.4898 val loss: 0.1949 train acc: 0.78 val acc: 0.94
# Epoch 3/24
# ----------
# eEpoch 4/25==> train loss: 0.4960 val loss: 0.2099 train acc: 0.78 val acc: 0.93
# Epoch 4/24
# ----------
# eEpoch 5/25==> train loss: 0.5094 val loss: 0.1590 train acc: 0.80 val acc: 0.95
# Epoch 5/24
# ----------
# eEpoch 6/25==> train loss: 0.2919 val loss: 0.1775 train acc: 0.90 val acc: 0.96
# Epoch 6/24
# ----------
# eEpoch 7/25==> train loss: 0.3845 val loss: 0.1639 train acc: 0.84 val acc: 0.96
# Epoch 7/24
# ----------
# eEpoch 8/25==> train loss: 0.4386 val loss: 0.1777 train acc: 0.81 val acc: 0.95
# Epoch 8/24
# ----------
# eEpoch 9/25==> train loss: 0.3213 val loss: 0.1610 train acc: 0.85 val acc: 0.95
# Epoch 9/24
# ----------
# eEpoch 10/25==> train loss: 0.3607 val loss: 0.1579 train acc: 0.82 val acc: 0.95
# Epoch 10/24
# ----------
# eEpoch 11/25==> train loss: 0.3821 val loss: 0.1723 train acc: 0.82 val acc: 0.95
# Epoch 11/24
# ----------
# eEpoch 12/25==> train loss: 0.2366 val loss: 0.1685 train acc: 0.90 val acc: 0.95
# Epoch 12/24
# ----------
# eEpoch 13/25==> train loss: 0.3373 val loss: 0.1567 train acc: 0.84 val acc: 0.95
# Epoch 13/24
# ----------
# eEpoch 14/25==> train loss: 0.2673 val loss: 0.1614 train acc: 0.88 val acc: 0.95
# Epoch 14/24
# ----------
# eEpoch 15/25==> train loss: 0.2958 val loss: 0.1662 train acc: 0.86 val acc: 0.95
# Epoch 15/24
# ----------
# eEpoch 16/25==> train loss: 0.3651 val loss: 0.1608 train acc: 0.85 val acc: 0.96
# Epoch 16/24
# ----------
# eEpoch 17/25==> train loss: 0.2678 val loss: 0.1561 train acc: 0.89 val acc: 0.95
# Epoch 17/24
# ----------
# eEpoch 18/25==> train loss: 0.3717 val loss: 0.1521 train acc: 0.84 val acc: 0.95
# Epoch 18/24
# ----------
# eEpoch 19/25==> train loss: 0.3355 val loss: 0.2325 train acc: 0.87 val acc: 0.90
# Epoch 19/24
# ----------
# eEpoch 20/25==> train loss: 0.3486 val loss: 0.1612 train acc: 0.84 val acc: 0.96
# Epoch 20/24
# ----------
# eEpoch 21/25==> train loss: 0.3355 val loss: 0.1641 train acc: 0.86 val acc: 0.94
# Epoch 21/24
# ----------
# eEpoch 22/25==> train loss: 0.3706 val loss: 0.1549 train acc: 0.82 val acc: 0.96
# Epoch 22/24
# ----------
# eEpoch 23/25==> train loss: 0.2890 val loss: 0.1589 train acc: 0.87 val acc: 0.96
# Epoch 23/24
# ----------
# eEpoch 24/25==> train loss: 0.2736 val loss: 0.1666 train acc: 0.89 val acc: 0.95
# Epoch 24/24
# ----------
# eEpoch 25/25==> train loss: 0.3555 val loss: 0.1767 train acc: 0.86 val acc: 0.94
# Training complete in 2m 39s
# Best val Acc: 0.960784

# %%
predictions = []
labels = []

with torch.no_grad():
    for x, y in val_loader:
        x, y = x.to(device), y.to(device)

        z = model_ft(x)
        _, preds = torch.max(z, 1)
        
        predictions.extend(preds.cpu().numpy())
        labels.extend(y.cpu().numpy())
        
    correct_indices = np.nonzero(np.array(predictions) == np.array(labels))[0]
    incorrect_indices = np.nonzero(np.array(predictions) != np.array(labels))[0]

print(f"accuracy = {len(correct_indices) / len(predictions) * 100:.2f} %" )
# Out:
# accuracy = 94.12 %

# %%
inputs = []
for i, idx in enumerate(correct_indices[:9]):
    inputs.append(val_data[idx][0])
out = torchvision.utils.make_grid(inputs, nrow=9)
plt.figure(figsize=(24, 8))
imshow(out, 'correct')

inputs = []
for i, idx in enumerate(incorrect_indices[:9]):
    inputs.append(val_data[idx][0])
out = torchvision.utils.make_grid(inputs, nrow=9)
plt.figure(figsize=(24, 8))
imshow(out, 'incorrect')
