# %% [markdown]
# ## 실습
#
# ### UCI Machine Learning Repository 의 Auto MPG dataset 을 사용하여 Regression 예측 model 작성
#
# auto-mpg.data - data file
# auto-mpg.names - data 설명 file
#
# 1. mpg:           continuous
# 2. cylinders:     multi-valued discrete
# 3. displacement:  continuous (배기량)
# 4. horsepower:    continuous
# 5. weight:        continuous
# 6. acceleration:  continuous
# 7. model year:    multi-valued discrete
# 8. origin:        multi-valued discrete, 1 - USA, 2 - Europe, 3 - Japan
# 9. car name:      string (unique for each instance)
#
# Missing Attribute Values:  horsepower has 6 missing values  ==> "?" 로 들어 있으므로 read_csv 시 nan 으로 변환

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn import functional as F

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %% [markdown]
# ### Data load 및 Preprocessing

# %%
from requests import get

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"
file_name = "auto-mpg.data"

with open(file_name, "wb") as file:
    response = get(url)
    file.write(response.content)

# %%
column_names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model year', 'origin']

rawdata = pd.read_csv(file_name, names=column_names, na_values="?", comment="\t", sep=" ", skipinitialspace=True)
rawdata.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    model year  origin
# 0          70       1
# 1          70       1
# 2          70       1
# 3          70       1
# 4          70       1

# %%
rawdata.dropna(inplace=True)

data = rawdata.copy()

data = pd.get_dummies(data, columns=['cylinders', 'origin'])

label = data.pop('mpg')

# %%
X_train, X_test, y_train, y_test = train_test_split(data.values, label.values, random_state=0)

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (294, 13) (98, 13) (294,) (98,)

# %%
X_train_ts = torch.FloatTensor(X_train)
X_test_ts = torch.FloatTensor(X_test)
y_train_ts = torch.FloatTensor(y_train).view(-1, 1)
y_test_ts = torch.FloatTensor(y_test).view(-1, 1)

# %% [markdown]
# ### Regression Model Build

# %%
class LinearReg(nn.Module):
    def __init__(self, input_size, output_size):
        super(LinearReg, self).__init__()
        self.fc1 = nn.Linear(input_size, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, output_size)
    
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        output = self.fc3(x)
        return output

# %%
model = LinearReg(X_train.shape[1], 1).to(device)

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
train_ds = torch.utils.data.TensorDataset(X_train_ts, y_train_ts)

train_loader = torch.utils.data.DataLoader(train_ds, batch_size=32, shuffle=True)

# %% [markdown]
# ### train

# %%
Loss = []
num_epochs = 500
for epoch in range(num_epochs):
    for x, y in train_loader:
        x, y = x.to(device), y.to(device)
        yhat = model(x)
        loss = criterion(yhat, y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print("epoch {} loss: {:.4f}".format(epoch + 1, loss.item()))
    Loss.append(loss.item())
# Out:
# epoch 1 loss: 568.9019
# epoch 2 loss: 318.7502
# epoch 3 loss: 664.2769
# epoch 4 loss: 546.5336
# epoch 5 loss: 450.2483
# epoch 6 loss: 603.5764
# epoch 7 loss: 265.5086
# epoch 8 loss: 190.6570
# epoch 9 loss: 87.6315
# epoch 10 loss: 72.3679
# epoch 11 loss: 21.4306
# epoch 12 loss: 44.2857
# epoch 13 loss: 12.8520
# epoch 14 loss: 14.7564
# epoch 15 loss: 16.8278
# epoch 16 loss: 25.9380
# epoch 17 loss: 7.6057
# epoch 18 loss: 26.2187
# epoch 19 loss: 10.8968
# epoch 20 loss: 8.4003
# epoch 21 loss: 31.3368
# epoch 22 loss: 10.4461
# epoch 23 loss: 7.5880
# epoch 24 loss: 3.6873
# epoch 25 loss: 5.4990
# epoch 26 loss: 4.1959
# epoch 27 loss: 9.4567
# epoch 28 loss: 4.7349
# epoch 29 loss: 2.9883
# epoch 30 loss: 5.9490
# epoch 31 loss: 5.3002
# epoch 32 loss: 3.0704
# epoch 33 loss: 9.4342
# epoch 34 loss: 6.5234
# epoch 35 loss: 14.4906
# epoch 420 loss: 2.6959
# epoch 421 loss: 5.3733
# epoch 422 loss: 0.5056
# epoch 423 loss: 0.6644
# epoch 424 loss: 1.0739
# epoch 425 loss: 2.1372
# epoch 426 loss: 5.7502
# epoch 427 loss: 8.2404
# epoch 428 loss: 2.8531
# epoch 429 loss: 3.8365
# epoch 430 loss: 1.1135
# epoch 431 loss: 1.8126
# epoch 432 loss: 23.6331
# epoch 433 loss: 2.6098
# epoch 434 loss: 6.8567
# epoch 435 loss: 2.4444
# epoch 436 loss: 0.8950
# epoch 437 loss: 1.9897
# epoch 438 loss: 1.7959
# epoch 439 loss: 2.9977
# epoch 440 loss: 29.5147
# epoch 441 loss: 3.5428
# epoch 442 loss: 6.7103
# epoch 443 loss: 5.1102
# epoch 444 loss: 0.7582
# epoch 445 loss: 4.4614
# epoch 446 loss: 2.5966
# epoch 447 loss: 2.4999
# epoch 448 loss: 7.9185
# epoch 449 loss: 2.6312
# epoch 450 loss: 1.5158
# epoch 451 loss: 7.2482
# epoch 452 loss: 6.8699
# epoch 453 loss: 1.7719
# epoch 454 loss: 8.9353
# epoch 455 loss: 1.4169
# epoch 456 loss: 1.5123
# epoch 457 loss: 9.7354
# epoch 458 loss: 0.6895
# epoch 459 loss: 0.3304
# epoch 460 loss: 1.9979
# epoch 461 loss: 1.0708
# epoch 462 loss: 2.0496
# epoch 463 loss: 2.1171
# epoch 464 loss: 6.2497
# epoch 465 loss: 3.1779
# epoch 466 loss: 2.3716
# epoch 467 loss: 1.6710
# epoch 468 loss: 1.9447
# epoch 469 loss: 1.1031
# epoch 470 loss: 2.4821
# epoch 471 loss: 1.7642
# epoch 472 loss: 2.5607
# epoch 473 loss: 8.6668
# epoch 474 loss: 5.4967
# epoch 475 loss: 1.3608
# epoch 476 loss: 1.1585
# epoch 477 loss: 1.4058
# epoch 478 loss: 1.9584
# epoch 479 loss: 1.7823
# epoch 480 loss: 3.2468
# epoch 481 loss: 1.8226
# epoch 482 loss: 2.0264
# epoch 483 loss: 3.3310
# epoch 484 loss: 2.5318
# epoch 485 loss: 1.2987
# epoch 486 loss: 3.8904
# epoch 487 loss: 2.6125
# epoch 488 loss: 23.9785
# epoch 489 loss: 1.5439
# epoch 490 loss: 5.5129
# epoch 491 loss: 2.2236
# epoch 492 loss: 1.9987
# epoch 493 loss: 0.9489
# epoch 494 loss: 1.2278
# epoch 495 loss: 3.2274
# epoch 496 loss: 0.7334
# epoch 497 loss: 6.2120
# epoch 498 loss: 1.6275
# epoch 499 loss: 2.8100
# epoch 500 loss: 1.9947

# %% [markdown]
# ### predict

# %%
y_pred = model(X_test_ts.to(device)).cpu().detach().numpy()

# %% [markdown]
# ### $r^2$ 계산

# %%
from sklearn.metrics import r2_score

r2_score(y_test, y_pred)
# Out:
# 0.8468438933085608

# %%
import matplotlib.pyplot as plt

plt.scatter(X_test[:, 0], y_test, c='b', label="true")
plt.scatter(X_test[:, 0], y_pred, c='r', label="prediction")
plt.xlabel('cylinders')
plt.ylabel('mpg')
plt.legend()
