# %% [markdown]
# # 160. mnist dataset 손글씨 인식 - Multi-class Classification
#
# - Basic Fully Connected Layer 이용
#
# - nn.CrossEntropyLoss 이용

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torchvision.transforms as transforms
from torchvision import datasets
from torch.utils.data.sampler import SubsetRandomSampler

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %% [markdown]
# ### Dataset handling
# - ``transforms.ToTensor()`` - image 를 tensor로 변환
# - ```SubsetSampler``` - 주어진 인덱스 목록에서 무작위로 비복원 추출

# %%
# download mnist data
train_data = datasets.MNIST(root='./data', train=True, 
                            download=True, transform=transforms.ToTensor())

test_data = datasets.MNIST(root='./data', train=False, 
                           download=True, transform=transforms.ToTensor())

# %%
print(train_data)
print()
print(test_data)
print()
print(train_data[0][0].shape)
print(train_data[0][1])
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: ./data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()
#
# Dataset MNIST
#     Number of datapoints: 10000
#     Root location: ./data
#     Split: Test
#     StandardTransform
# Transform: ToTensor()
#
# torch.Size([1, 28, 28])
# 5

# %%
train_data[0][0]
# Out:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0118, 0.0706, 0.0706, 0.0706,
#           0.4941, 0.5333, 0.6863, 0.1020, 0.6510, 1.0000, 0.9686, 0.4980,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.1176, 0.1412, 0.3686, 0.6039, 0.6667, 0.9922, 0.9922, 0.9922,
#           0.9922, 0.9922, 0.8824, 0.6745, 0.9922, 0.9490, 0.7647, 0.2510,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1922,
#           0.9333, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922,
#           0.9922, 0.9843, 0.3647, 0.3216, 0.3216, 0.2196, 0.1529, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0706,
#           0.8588, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.7765, 0.7137,
#           0.9686, 0.9451, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.3137, 0.6118, 0.4196, 0.9922, 0.9922, 0.8039, 0.0431, 0.0000,
#           0.1686, 0.6039, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0549, 0.0039, 0.6039, 0.9922, 0.3529, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.5451, 0.9922, 0.7451, 0.0078, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0431, 0.7451, 0.9922, 0.2745, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.1373, 0.9451, 0.8824, 0.6275,
#           0.4235, 0.0039, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3176, 0.9412, 0.9922,
#           0.9922, 0.4667, 0.0980, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1765, 0.7294,
#           0.9922, 0.9922, 0.5882, 0.1059, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0627,
#           0.3647, 0.9882, 0.9922, 0.7333, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.9765, 0.9922, 0.9765, 0.2510, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1804, 0.5098,
#           0.7176, 0.9922, 0.9922, 0.8118, 0.0078, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.1529, 0.5804, 0.8980, 0.9922,
#           0.9922, 0.9922, 0.9804, 0.7137, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0941, 0.4471, 0.8667, 0.9922, 0.9922, 0.9922,
#           0.9922, 0.7882, 0.3059, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0902, 0.2588, 0.8353, 0.9922, 0.9922, 0.9922, 0.9922, 0.7765,
#           0.3176, 0.0078, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0706, 0.6706,
#           0.8588, 0.9922, 0.9922, 0.9922, 0.9922, 0.7647, 0.3137, 0.0353,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.2157, 0.6745, 0.8863, 0.9922,
#           0.9922, 0.9922, 0.9922, 0.9569, 0.5216, 0.0431, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.5333, 0.9922, 0.9922, 0.9922,
#           0.8314, 0.5294, 0.5176, 0.0627, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]])

# %% [markdown]
# - Data 시각화

# %%
plt.figure(figsize=(25, 6))

for i, (x, y) in enumerate(test_data):
    if i > 19:
        break
    plt.subplot(2, 10, i+1)
    plt.imshow(x.view(28, 28), cmap='gray')  
    plt.title("Class {}".format(y))
    plt.xticks([])
    plt.yticks([])

plt.show()

# %% [markdown]
# ## Dataset Loader 생성
#
# - Train dataset 을 Train 과 Validation set 으로 분리

# %%
valid_size = 0.2  # validation set 으로 사용할 train_dataset size

num_train = len(train_data)
indices = list(range(num_train))

np.random.shuffle(indices)   # shuffle data
split = int(np.floor(valid_size * num_train))  #split data size
train_idx, valid_idx = indices[split:], indices[:split]

# sampler 정의
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# %% [markdown]
# - train, validation, test dataset 으로 3 분할

# %%
batch_size = 128
train_loader = torch.utils.data.DataLoader(dataset=train_data, 
                                batch_size=batch_size, sampler=train_sampler)
valid_loader = torch.utils.data.DataLoader(dataset=train_data, 
                                batch_size=batch_size, sampler=valid_sampler)
test_loader  = torch.utils.data.DataLoader(dataset=test_data, 
                                batch_size=batch_size, shuffle=False)

# %% [markdown]
# ### Model custom build
#
# - nn.Linear 이용
# - activation 으로 relu 함수 적용
# - 2개의 hidden layer와 dropout 사용
#
# <img src="linear.png" width="600" />

# %%
class Net(nn.Module):
    def __init__(self, D_in, H, D_out):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(D_in, H)
        self.fc2 = nn.Linear(H, H)
        self.fc3 = nn.Linear(H, D_out)
        self.dropout = nn.Dropout(0.2)
        self.relu  = nn.ReLU()
        
    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.relu(self.fc2(x))
        x = self.dropout(x)
        out = self.fc3(x)
        return out

# %%
input_dim = 28 * 28
hidden_dim = 128
output_dim = 10

model = Net(input_dim, hidden_dim, output_dim)

# %% [markdown]
# ### Model Summary

# %%
model
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=128, bias=True)
#   (fc3): Linear(in_features=128, out_features=10, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (relu): ReLU()
# )

# %%
for k, v in model.state_dict().items():
    print(k, v.numel())
    
print("total trainable params", sum(p.numel() for p in model.parameters()))
# Out:
# fc1.weight 100352
# fc1.bias 128
# fc2.weight 16384
# fc2.bias 128
# fc3.weight 1280
# fc3.bias 10
# total trainable params 118282

# %%
for images, labels in train_loader:
    probs = model(images[0].view(-1, 28*28))
    break

print('outputs.shape : ', probs.shape)
# Look at sample probabilities
print("Sample probabilities:\n", probs[0].data)
# torch.argmax 로 가장 확률이 높은 output 선택
pred = torch.argmax(probs, dim=1)
pred
# Out:
# outputs.shape :  torch.Size([1, 10])
# Sample probabilities:
#  tensor([-0.0082,  0.0569, -0.0731,  0.0119,  0.0954, -0.0755,  0.0513,  0.0850,
#         -0.0487,  0.0318])
# tensor([4])

# %% [markdown]
# ### softmax 함수를 사용하여 output row 를 확률 분포로 바꾼다. 공식은 다음과 같다.
#
#
# <img src="softmax.png" width="400" />
#
# - output row 의 각 element $y_i$ 를 $e^{y_i}$ 로 변경하여 모든 element 를 양수로 만든다.
# - 각 element 를 모든 element 의 합으로 나누어 합계가 1 이 되도록 한다.
# - predicted label 은 torch.max 를 이용하여 각 row 에서 highest probability 값을 고른다.

# %% [markdown]
# ### Loss Function 정의
#
# <img src="crossentropy.png" width="400" />

# %% [markdown]
# - 손실함수는 categorical cross-entropy 지정

# %%
criterion = nn.CrossEntropyLoss()

model.to(device)
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=128, bias=True)
#   (fc3): Linear(in_features=128, out_features=10, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (relu): ReLU()
# )

# %% [markdown]
# - optimizer 는 Stochastic Gradient Descent 사용

# %%
lr = 0.01
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

# %%
LOSS, VAL_LOSS, ACC, VAL_ACC = [], [], [], []
EPOCHS = 50

for epoch in range(EPOCHS):
    
    model.train()  # train mode
    
    train_loss = 0
    train_acc  = 0
    for x, y in train_loader:
        x, y = x.to(device), y.to(device)
        
        z = model(x.view(-1, 28 * 28))
        loss = criterion(z, y)
        train_loss += loss.item()
        _, y_pred = torch.max(z, 1)  # (max values, indices)
        train_acc += (y_pred == y).sum().item()
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    train_loss = train_loss / len(train_loader)
    train_acc  = train_acc / len(train_loader)
    LOSS.append(train_loss)
    ACC.append(train_acc)
        
    model.eval()  #evaluaion mode
    
    val_loss = 0
    val_acc = 0
    for x, y in valid_loader:
        x, y = x.to(device), y.to(device)

        z = model(x.view(-1, 28 * 28))
        loss = criterion(z, y)
        val_loss += loss.item()
        _, y_pred = torch.max(z, 1)
        val_acc += (y_pred == y).sum().item()
    
    val_loss = val_loss / len(valid_loader)
    val_acc  = val_acc / len(valid_loader)
    VAL_LOSS.append(val_loss)
    VAL_ACC.append(val_acc)

    print(f'epoch {epoch} ==> train loss: {train_loss:.5f},  \
          valididation loss: {val_loss:.5f}',  \
                    f'train acc: {train_acc:.5f}, validation acc: {val_acc:.5f}')
# Out:
# epoch 0 ==> train loss: 2.21348,            valididation loss: 2.02327 train acc: 47.91200, validation acc: 79.08511
# epoch 1 ==> train loss: 1.61294,            valididation loss: 1.10642 train acc: 79.45600, validation acc: 98.82979
# epoch 2 ==> train loss: 0.94504,            valididation loss: 0.68753 train acc: 93.78400, validation acc: 105.76596
# epoch 3 ==> train loss: 0.70322,            valididation loss: 0.54181 train acc: 101.49333, validation acc: 109.36170
# epoch 4 ==> train loss: 0.59340,            valididation loss: 0.46943 train acc: 105.61600, validation acc: 111.07447
# epoch 5 ==> train loss: 0.53033,            valididation loss: 0.42362 train acc: 108.19200, validation acc: 112.62766
# epoch 6 ==> train loss: 0.48360,            valididation loss: 0.39279 train acc: 109.78400, validation acc: 113.36170
# epoch 7 ==> train loss: 0.44967,            valididation loss: 0.37097 train acc: 111.34933, validation acc: 114.17021
# epoch 8 ==> train loss: 0.42611,            valididation loss: 0.35272 train acc: 112.18933, validation acc: 114.72340
# epoch 9 ==> train loss: 0.40593,            valididation loss: 0.33815 train acc: 112.78133, validation acc: 115.10638
# epoch 10 ==> train loss: 0.39164,            valididation loss: 0.32695 train acc: 113.33333, validation acc: 115.46809
# epoch 11 ==> train loss: 0.37554,            valididation loss: 0.31595 train acc: 113.99200, validation acc: 115.82979
# epoch 12 ==> train loss: 0.36428,            valididation loss: 0.30541 train acc: 114.24000, validation acc: 116.31915
# epoch 13 ==> train loss: 0.35248,            valididation loss: 0.29586 train acc: 115.03200, validation acc: 116.69149
# epoch 14 ==> train loss: 0.34046,            valididation loss: 0.28715 train acc: 115.30400, validation acc: 117.04255
# epoch 15 ==> train loss: 0.32848,            valididation loss: 0.27966 train acc: 115.62400, validation acc: 117.22340
# epoch 16 ==> train loss: 0.32140,            valididation loss: 0.27124 train acc: 115.98667, validation acc: 117.59574
# epoch 17 ==> train loss: 0.30943,            valididation loss: 0.26348 train acc: 116.45333, validation acc: 117.82979
# epoch 18 ==> train loss: 0.30319,            valididation loss: 0.25653 train acc: 116.58400, validation acc: 118.08511
# epoch 19 ==> train loss: 0.29549,            valididation loss: 0.24991 train acc: 116.82933, validation acc: 118.29787
# epoch 20 ==> train loss: 0.28701,            valididation loss: 0.24323 train acc: 117.41067, validation acc: 118.51064
# epoch 21 ==> train loss: 0.27956,            valididation loss: 0.23641 train acc: 117.54400, validation acc: 118.92553
# epoch 22 ==> train loss: 0.27070,            valididation loss: 0.23034 train acc: 117.85867, validation acc: 119.13830
# epoch 23 ==> train loss: 0.26215,            valididation loss: 0.22483 train acc: 118.27467, validation acc: 119.39362
# epoch 24 ==> train loss: 0.25821,            valididation loss: 0.22003 train acc: 118.41067, validation acc: 119.40426
# epoch 25 ==> train loss: 0.25320,            valididation loss: 0.21442 train acc: 118.49867, validation acc: 119.68085
# epoch 26 ==> train loss: 0.24782,            valididation loss: 0.20948 train acc: 118.79733, validation acc: 119.86170
# epoch 27 ==> train loss: 0.24280,            valididation loss: 0.20459 train acc: 118.98667, validation acc: 120.05319
# epoch 28 ==> train loss: 0.23701,            valididation loss: 0.20014 train acc: 119.09067, validation acc: 120.21277
# epoch 29 ==> train loss: 0.23231,            valididation loss: 0.19542 train acc: 119.32533, validation acc: 120.41489
# epoch 30 ==> train loss: 0.22620,            valididation loss: 0.19149 train acc: 119.62933, validation acc: 120.47872
# epoch 31 ==> train loss: 0.22209,            valididation loss: 0.18798 train acc: 119.69333, validation acc: 120.56383
# epoch 32 ==> train loss: 0.21808,            valididation loss: 0.18518 train acc: 119.98933, validation acc: 120.81915
# epoch 33 ==> train loss: 0.21182,            valididation loss: 0.18117 train acc: 120.07467, validation acc: 120.79787
# epoch 34 ==> train loss: 0.20972,            valididation loss: 0.17790 train acc: 120.28267, validation acc: 120.98936
# epoch 35 ==> train loss: 0.20480,            valididation loss: 0.17466 train acc: 120.48267, validation acc: 121.14894
# epoch 36 ==> train loss: 0.20171,            valididation loss: 0.17189 train acc: 120.38133, validation acc: 121.24468
# epoch 37 ==> train loss: 0.20004,            valididation loss: 0.16902 train acc: 120.54133, validation acc: 121.32979
# epoch 38 ==> train loss: 0.19520,            valididation loss: 0.16621 train acc: 120.70133, validation acc: 121.44681
# epoch 39 ==> train loss: 0.19154,            valididation loss: 0.16329 train acc: 120.88800, validation acc: 121.55319
# epoch 40 ==> train loss: 0.18641,            valididation loss: 0.16096 train acc: 120.98933, validation acc: 121.59574
# epoch 41 ==> train loss: 0.18321,            valididation loss: 0.15851 train acc: 121.19467, validation acc: 121.55319
# epoch 42 ==> train loss: 0.18206,            valididation loss: 0.15688 train acc: 121.36000, validation acc: 121.73404
# epoch 43 ==> train loss: 0.17960,            valididation loss: 0.15425 train acc: 121.23200, validation acc: 121.76596
# epoch 44 ==> train loss: 0.17761,            valididation loss: 0.15250 train acc: 121.43467, validation acc: 121.77660
# epoch 45 ==> train loss: 0.17512,            valididation loss: 0.14995 train acc: 121.38400, validation acc: 121.97872
# epoch 46 ==> train loss: 0.17454,            valididation loss: 0.14802 train acc: 121.59200, validation acc: 122.03191
# epoch 47 ==> train loss: 0.16771,            valididation loss: 0.14572 train acc: 121.77067, validation acc: 122.05319
# epoch 48 ==> train loss: 0.16617,            valididation loss: 0.14432 train acc: 121.71733, validation acc: 122.11702
# epoch 49 ==> train loss: 0.16599,            valididation loss: 0.14249 train acc: 121.77067, validation acc: 122.21277

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
ax1.plot(LOSS, label='train loss')
ax1.plot(VAL_LOSS, label='validation loss')
ax1.set_xlabel('epoch')
ax1.set_ylabel('loss')
ax1.legend()
ax2.plot(ACC, label='train accuracy')
ax2.plot(VAL_ACC, label='validation accuracy')
ax2.set_xlabel('epoch')
ax2.set_ylabel('accuracy')
ax2.legend()

# %% [markdown]
# ## Model 평가 - Test set 사용

# %%
predictions = []
labels = []

model.eval()

for x, y in test_loader:
    x, y = x.to(device), y.to(device)
    z = model(x.view(-1, 28 * 28))
    _, y_pred = torch.max(z, 1)
    
    predictions.extend(y_pred.cpu().numpy())
    labels.extend(y.cpu().numpy())
    
correct_indices = np.nonzero(np.array(predictions) == np.array(labels))[0]
incorrect_indices = np.nonzero(np.array(predictions) != np.array(labels))[0]
    
print("accuracy = {:.2f}%".format(len(correct_indices) / len(predictions) * 100))
# Out:
# accuracy = 95.99%

# %% [markdown]
# ## Category 별 분류 성능 측정

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(labels, predictions)
plt.figure(figsize=(8, 6))
ax = sns.heatmap(cm, annot=True, fmt='d')
ax.set_xlabel('True value')
ax.set_ylabel('Predicted Value')

for i in range(10):
    print(f"accuracy of {i} = {cm[i][i] / cm[i].sum() * 100:.2f}%")
# Out:
# accuracy of 0 = 98.57%
# accuracy of 1 = 98.41%
# accuracy of 2 = 95.16%
# accuracy of 3 = 95.94%
# accuracy of 4 = 96.54%
# accuracy of 5 = 94.17%
# accuracy of 6 = 96.87%
# accuracy of 7 = 95.62%
# accuracy of 8 = 94.66%
# accuracy of 9 = 93.56%

# %% [markdown]
# ## Sample Test 결과 시각화

# %%
# %matplotlib inline

plt.figure(figsize=(6, 6))
for i, idx in enumerate(correct_indices[:9]):
    plt.subplot(3, 3, i+1)
    plt.imshow(test_data[idx][0].view(28, 28), cmap='gray')
    plt.title("Predicted {}, True {}".format(predictions[idx], labels[idx]))
    plt.xticks([])
    plt.yticks([])
plt.tight_layout()

plt.figure(figsize=(6, 6))
for i, idx in enumerate(incorrect_indices[:9]):
    plt.subplot(3, 3, i+1)
    plt.imshow(test_data[idx][0].view(28, 28), cmap='gray')
    plt.title("Predicted {}, True {}".format(predictions[idx], labels[idx]))
    plt.xticks([])
    plt.yticks([])
plt.tight_layout()
